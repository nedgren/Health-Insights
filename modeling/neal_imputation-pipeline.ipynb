# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, KFold
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error

#We may want these at some point for transforming our output:
#from scipy.special import logit, expit

# %%
pd.set_option('display.max_columns', None) #forces all columns to be displayed
pd.set_option('display.max_rows', None) #forces all rows to be displayed

# %%
filepath = '../data/data_reduced_train.csv'
data = pd.read_csv(filepath)

# %%
data.head()
# Out:
#     FIPS         State     County  % Adults with Diabetes  \
# 0  17027      Illinois    Clinton                     8.7
# 1  42071  Pennsylvania  Lancaster                     8.2
# 2  46003  South Dakota     Aurora                     8.2
# 3  46027  South Dakota       Clay                     9.2
# 4  13205       Georgia   Mitchell                    15.9
#
#    % Adults Reporting Currently Smoking  % Adults with Obesity  \
# 0                                  16.7                   34.8
# 1                                  16.7                   35.2
# 2                                  17.0                   38.8
# 3                                  16.3                   35.6
# 4                                  22.8                   42.2
#
#    Food Environment Index  % Physically Inactive  \
# 0                     9.0                   25.8
# 1                     8.8                   23.4
# 2                     7.8                   23.1
# 3                     7.6                   22.2
# 4                     6.8                   34.5
#
#    % With Access to Exercise Opportunities  % Excessive Drinking  ...  \
# 0                                63.809317             18.658612  ...
# 1                                80.948635             17.168046  ...
# 2                                 3.349108             21.089477  ...
# 3                                85.568250             22.062377  ...
# 4                                59.917260             13.354151  ...
#
#    % 65 and Over    % Black  % American Indian or Alaska Native   % Asian  \
# 0      18.662115   3.243111                            0.403696  0.655667
# 1      19.735587   3.722587                            0.474823  2.778152
# 2      21.125227   0.907441                            2.903811  0.943739
# 3      12.624346   1.760471                            4.011780  2.729058
# 4      18.407842  45.870430                            0.672476  0.975564
#
#    % Native Hawaiian or Other Pacific Islander  % Hispanic  \
# 0                                     0.083990    3.541142
# 1                                     0.114798   11.589407
# 2                                     0.000000    8.457350
# 3                                     0.065445    3.331152
# 4                                     0.066300    5.479257
#
#    % Non-Hispanic White  % Not Proficient in English   % Female     % Rural
# 0             91.007613                     0.535157  47.787802   80.216266
# 1             80.193630                     2.150077  50.747266   27.875490
# 2             85.880218                     1.615576  48.566243  100.000000
# 3             86.302356                     0.406533  50.425393   22.101958
# 4             46.126160                     0.725704  49.720591   75.775684
#
# [5 rows x 52 columns]

# %%
#we may not even need to drop these anymore
#data_drop_null_state_features = data.drop(columns=['% Voter Turnout', 'School Funding Adequacy'])

# %%
len(data.columns)
# Out:
# 52

# %%
features = data.columns[4:]
target = '% Adults with Diabetes'

# %%
data_train, data_holdout = train_test_split(data,
                                        shuffle=True,
                                        random_state=42,
                                        test_size=0.2)

# %%
X_train = data_train[features]
y_train = data_train[target]
X_holdout = data_holdout[features]
y_holdout = data_holdout[target]

# %%
xgb_pipe = Pipeline([('impute', KNNImputer()),
                     ('xgb', XGBRegressor())])

xgb_pipe.fit(X_train, y_train)
xgb_train_preds = xgb_pipe.predict(X_train)

# %%
xgb_model = XGBRegressor()
xgb_model.fit(X_train, y_train)
xgb_model_train_preds = xgb_model.predict(X_train)

# %%
print('XGB Training RMSE with kNNImputer:', root_mean_squared_error(y_train, xgb_train_preds))
print('XGB Training RMSE without imputing:', root_mean_squared_error(y_train, xgb_model_train_preds))
# Out:
# Train RMSE with kNNImputer: 0.015976972268687
# Train RMSE without imputing: 0.016927218715798713

# %% [markdown]
# ## Below, we do a quick sanity check to ensure that the imputer is not giving us wild values

# %%
imputer = KNNImputer()

array = imputer.fit_transform(X_train)

# %%
np.isnan(array).sum().sum()
# Out:
# np.int64(0)

# %%
X_train_imputed = pd.DataFrame(data=array, columns=X_train.columns)

# %%
X_train_imputed.describe()
# Out:
#        % Adults Reporting Currently Smoking  % Adults with Obesity  \
# count                           2010.000000            2010.000000
# mean                              19.080846              37.366318
# std                                4.174719               4.555487
# min                                7.000000              17.400000
# 25%                               16.400000              35.100000
# 50%                               18.700000              37.700000
# 75%                               21.600000              40.200000
# max                               43.000000              51.000000
#
#        Food Environment Index  % Physically Inactive  \
# count             2010.000000            2010.000000
# mean                 7.570677              26.642040
# std                  1.177204               5.192249
# min                  0.000000              12.000000
# 25%                  7.000000              23.100000
# 50%                  7.700000              26.300000
# 75%                  8.400000              30.000000
# max                 10.000000              47.000000
#
#        % With Access to Exercise Opportunities  % Excessive Drinking  \
# count                              2010.000000           2010.000000
# mean                                 61.576795             16.858568
# std                                  22.919207              2.611362
# min                                   0.000000              9.038096
# 25%                                  46.742619             15.050318
# 50%                                  64.068279             16.854673
# 75%                                  78.846767             18.465536
# max                                 100.000000             26.134563
#
#        % Driving Deaths with Alcohol Involvement  % Uninsured  Dentist Rate  \
# count                                2010.000000  2010.000000   2010.000000
# mean                                   27.375944    11.440834     47.831436
# std                                    15.154552     5.174442     32.008737
# min                                     0.000000     2.389743      0.000000
# 25%                                    18.518519     7.465734     27.322985
# 50%                                    26.315789    10.307064     42.568895
# 75%                                    33.333333    14.539297     64.014583
# max                                   100.000000    32.747535    349.650350
#
#        % with Annual Mammogram  % Vaccinated  % Completed High School  \
# count              2010.000000   2010.000000              2010.000000
# mean                 41.730348     40.107662                88.303045
# std                   8.139939     10.406799                 5.622573
# min                   6.000000      2.000000                54.906334
# 25%                  37.000000     33.000000                85.227729
# 50%                  42.000000     41.000000                89.436084
# 75%                  47.000000     47.900000                92.477047
# max                  64.000000     68.000000                99.690402
#
#        % Unemployed  % Children in Poverty  Income Ratio  \
# count   2010.000000            2010.000000   2010.000000
# mean       3.582974              19.349751      4.555425
# std        1.212205               8.266860      0.823503
# min        0.859107               2.400000      2.410432
# 25%        2.724356              13.400000      4.015577
# 50%        3.410447              18.100000      4.434182
# 75%        4.203793              23.875000      4.953463
# max       12.910382              55.000000     10.532338
#
#        % Children in Single-Parent Households  Social Association Rate  \
# count                             2010.000000              2010.000000
# mean                                23.916172                11.297751
# std                                 10.406909                 5.887015
# min                                  0.000000                 0.000000
# 25%                                 16.961015                 7.873410
# 50%                                 22.156167                10.720041
# 75%                                 28.720613                14.136010
# max                                 78.519291                59.435364
#
#        Average Daily PM2.5  % Severe Housing Problems  % Drive Alone to Work  \
# count          2010.000000                2010.000000            2010.000000
# mean              7.509075                  12.898025              77.685944
# std               1.707951                   4.548764               7.820264
# min               2.200000                   2.526316               5.668390
# 25%               6.500000                  10.219265              74.906346
# 50%               7.700000                  12.352907              78.999341
# 75%               8.800000                  14.785700              82.253066
# max              15.600000                  61.142857              94.245723
#
#        % Long Commute - Drives Alone  % Food Insecure  \
# count                    2010.000000      2010.000000
# mean                       33.003234        11.412139
# std                        12.619063         3.552768
# min                         0.000000         2.200000
# 25%                        23.600000         8.900000
# 50%                        32.400000        11.100000
# 75%                        41.600000        13.800000
# max                        73.300000        26.300000
#
#        % Limited Access to Healthy Foods  % Insufficient Sleep  \
# count                        2010.000000           2010.000000
# mean                            8.385946             34.479831
# std                             7.353854              3.641291
# min                             0.000000             23.800000
# 25%                             3.703208             31.900000
# 50%                             6.536077             34.500000
# 75%                            10.702867             36.800000
# max                            62.599918             46.900000
#
#        % Uninsured Children  Other Primary Care Provider Rate  \
# count           2010.000000                       2010.000000
# mean               6.480667                        109.106245
# std                3.575343                         72.868849
# min                0.684932                          0.000000
# 25%                4.072028                         66.291320
# 50%                5.494948                         93.765490
# 75%                7.882996                        135.788755
# max               31.179735                        905.641470
#
#        School Funding Adequacy  Gender Pay Gap  Median Household Income  \
# count              2010.000000     2010.000000              2010.000000
# mean              -1884.920319        0.782768             63283.775124
# std                7648.579193        0.101792             16349.712888
# min              -63405.880000        0.315462             28972.000000
# 25%               -4425.575152        0.727727             52522.250000
# 50%                -845.382350        0.781011             60833.500000
# 75%                2013.453687        0.833934             70497.000000
# max               32379.685000        1.728074            167605.000000
#
#        % Household Income Required for Child Care Expenses  % Voter Turnout  \
# count                                        2010.000000        2010.000000
# mean                                           27.740609          65.614183
# std                                             6.207529          10.028628
# min                                             7.064892          32.939271
# 25%                                            23.684258          58.922135
# 50%                                            27.326022          65.660292
# 75%                                            31.303697          72.581944
# max                                            80.474882         100.000000
#
#        % Census Participation  Traffic Volume  % Homeowners  \
# count             2010.000000     2010.000000   2010.000000
# mean                58.232488       46.708529     72.731450
# std                 12.142842       85.092645      8.448679
# min                  1.200000        0.000332     19.963760
# 25%                 50.700000        8.726006     68.372645
# 50%                 59.800000       24.715576     73.933780
# 75%                 67.400000       51.692614     78.424408
# max                 83.400000     1753.934509     96.985816
#
#        % Households with Severe Cost Burden  \
# count                           2010.000000
# mean                              10.975752
# std                                3.542817
# min                                0.595238
# 25%                                8.552134
# 50%                               10.494738
# 75%                               12.865166
# max                               31.169239
#
#        % Households with Broadband Access    Population  \
# count                         2010.000000  2.010000e+03
# mean                            82.345228  1.067082e+05
# std                              7.230942  3.517858e+05
# min                             47.336501  2.330000e+02
# 25%                             78.526993  1.099775e+04
# 50%                             83.424161  2.599650e+04
# 75%                             87.230051  6.801375e+04
# max                            100.000000  9.721138e+06
#
#        % Less than 18 Years of Age  % 65 and Over      % Black  \
# count                  2010.000000    2010.000000  2010.000000
# mean                     21.683466      20.450801     8.847672
# std                       3.581355       4.822241    13.945457
# min                       3.546634       6.299112     0.000000
# 25%                      19.602721      17.313146     0.843511
# 50%                      21.678597      20.104667     2.325080
# 75%                      23.638154      23.220098     9.722577
# max                      42.099541      42.459275    82.122697
#
#        % American Indian or Alaska Native      % Asian  \
# count                         2010.000000  2010.000000
# mean                             2.601479     1.695258
# std                              8.322901     3.082494
# min                              0.000000     0.000000
# 25%                              0.444085     0.537928
# 50%                              0.747352     0.818378
# 75%                              1.522712     1.520247
# max                             92.111621    46.380224
#
#        % Native Hawaiian or Other Pacific Islander   % Hispanic  \
# count                                  2010.000000  2010.000000
# mean                                      0.148835    10.194657
# std                                       0.396069    13.461868
# min                                       0.000000     0.732961
# 25%                                       0.040193     2.818790
# 50%                                       0.076756     5.100209
# 75%                                       0.141910    11.064310
# max                                      10.414296    95.291657
#
#        % Non-Hispanic White  % Not Proficient in English     % Female  \
# count           2010.000000                  2010.000000  2010.000000
# mean              75.060171                     1.568745    49.488312
# std               20.109038                     2.558139     2.297528
# min                2.693887                     0.000000    27.039544
# 25%               63.039319                     0.244788    48.963481
# 50%               82.132857                     0.682820    49.870434
# 75%               91.420332                     1.741557    50.613384
# max               97.539986                    32.084894    57.762420
#
#            % Rural
# count  2010.000000
# mean     64.276710
# std      33.679398
# min       0.000000
# 25%      35.612502
# 50%      67.478110
# 75%     100.000000
# max     100.000000

# %%
X_train.describe()
# Out:
#        % Adults Reporting Currently Smoking  % Adults with Obesity  \
# count                           2010.000000            2010.000000
# mean                              19.080846              37.366318
# std                                4.174719               4.555487
# min                                7.000000              17.400000
# 25%                               16.400000              35.100000
# 50%                               18.700000              37.700000
# 75%                               21.600000              40.200000
# max                               43.000000              51.000000
#
#        Food Environment Index  % Physically Inactive  \
# count             1983.000000            2010.000000
# mean                 7.567625              26.642040
# std                  1.180937               5.192249
# min                  0.000000              12.000000
# 25%                  6.950000              23.100000
# 50%                  7.700000              26.300000
# 75%                  8.400000              30.000000
# max                 10.000000              47.000000
#
#        % With Access to Exercise Opportunities  % Excessive Drinking  \
# count                              1981.000000           2010.000000
# mean                                 61.803914             16.858568
# std                                  22.963970              2.611362
# min                                   0.000000              9.038096
# 25%                                  47.185161             15.050318
# 50%                                  64.536631             16.854673
# 75%                                  79.116829             18.465536
# max                                 100.000000             26.134563
#
#        % Driving Deaths with Alcohol Involvement  % Uninsured  Dentist Rate  \
# count                                1991.000000  2010.000000   1958.000000
# mean                                   27.373329    11.440834     48.055012
# std                                    15.194709     5.174442     32.301401
# min                                     0.000000     2.389743      0.000000
# 25%                                    18.518519     7.465734     27.337245
# 50%                                    26.315789    10.307064     42.717280
# 75%                                    33.333333    14.539297     64.454988
# max                                   100.000000    32.747535    349.650350
#
#        % with Annual Mammogram  % Vaccinated  % Completed High School  \
# count              1998.000000   1999.000000              2010.000000
# mean                 41.733233     40.123562                88.303045
# std                   8.156482     10.421125                 5.622573
# min                   6.000000      2.000000                54.906334
# 25%                  37.000000     34.000000                85.227729
# 50%                  42.000000     41.000000                89.436084
# 75%                  47.000000     48.000000                92.477047
# max                  64.000000     68.000000                99.690402
#
#        % Unemployed  % Children in Poverty  Income Ratio  \
# count   2010.000000            2010.000000   1999.000000
# mean       3.582974              19.349751      4.556363
# std        1.212205               8.266860      0.825153
# min        0.859107               2.400000      2.410432
# 25%        2.724356              13.400000      4.014312
# 50%        3.410447              18.100000      4.433995
# 75%        4.203793              23.875000      4.956377
# max       12.910382              55.000000     10.532338
#
#        % Children in Single-Parent Households  Social Association Rate  \
# count                             2010.000000              2010.000000
# mean                                23.916172                11.297751
# std                                 10.406909                 5.887015
# min                                  0.000000                 0.000000
# 25%                                 16.961015                 7.873410
# 50%                                 22.156167                10.720041
# 75%                                 28.720613                14.136010
# max                                 78.519291                59.435364
#
#        Average Daily PM2.5  % Severe Housing Problems  % Drive Alone to Work  \
# count          1991.000000                2010.000000            2010.000000
# mean              7.525565                  12.898025              77.685944
# std               1.704615                   4.548764               7.820264
# min               2.200000                   2.526316               5.668390
# 25%               6.500000                  10.219265              74.906346
# 50%               7.700000                  12.352907              78.999341
# 75%               8.800000                  14.785700              82.253066
# max              15.600000                  61.142857              94.245723
#
#        % Long Commute - Drives Alone  % Food Insecure  \
# count                    2010.000000      2010.000000
# mean                       33.003234        11.412139
# std                        12.619063         3.552768
# min                         0.000000         2.200000
# 25%                        23.600000         8.900000
# 50%                        32.400000        11.100000
# 75%                        41.600000        13.800000
# max                        73.300000        26.300000
#
#        % Limited Access to Healthy Foods  % Insufficient Sleep  \
# count                        1983.000000           2008.000000
# mean                            8.411310             34.483416
# std                             7.390631              3.641330
# min                             0.000000             23.800000
# 25%                             3.673220             31.900000
# 50%                             6.620099             34.500000
# 75%                            10.767675             36.825000
# max                            62.599918             46.900000
#
#        % Uninsured Children  Other Primary Care Provider Rate  \
# count           2010.000000                       2002.000000
# mean               6.480667                        109.189530
# std                3.575343                         72.979658
# min                0.684932                          0.000000
# 25%                4.072028                         66.291320
# 50%                5.494948                         93.765490
# 75%                7.882996                        135.842655
# max               31.179735                        905.641470
#
#        School Funding Adequacy  Gender Pay Gap  Median Household Income  \
# count              1958.000000     2007.000000              2010.000000
# mean              -1880.567395        0.782694             63283.775124
# std                7649.918424        0.101809             16349.712888
# min              -63405.880000        0.315462             28972.000000
# 25%               -4425.575152        0.727733             52522.250000
# 50%                -868.947300        0.781007             60833.500000
# 75%                2004.103336        0.833872             70497.000000
# max               32379.685000        1.728074            167605.000000
#
#        % Household Income Required for Child Care Expenses  % Voter Turnout  \
# count                                        2010.000000        1989.000000
# mean                                           27.740609          65.518577
# std                                             6.207529          10.001493
# min                                             7.064892          32.939271
# 25%                                            23.684258          58.895887
# 50%                                            27.326022          65.536954
# 75%                                            31.303697          72.447183
# max                                            80.474882         100.000000
#
#        % Census Participation  Traffic Volume  % Homeowners  \
# count             2007.000000     1992.000000   2010.000000
# mean                58.247583       47.070420     72.731450
# std                 12.144958       85.389829      8.448679
# min                  1.200000        0.000332     19.963760
# 25%                 50.700000        8.889837     68.372645
# 50%                 59.800000       25.105147     73.933780
# 75%                 67.400000       52.178669     78.424408
# max                 83.400000     1753.934509     96.985816
#
#        % Households with Severe Cost Burden  \
# count                           2010.000000
# mean                              10.975752
# std                                3.542817
# min                                0.595238
# 25%                                8.552134
# 50%                               10.494738
# 75%                               12.865166
# max                               31.169239
#
#        % Households with Broadband Access    Population  \
# count                         2010.000000  2.010000e+03
# mean                            82.345228  1.067082e+05
# std                              7.230942  3.517858e+05
# min                             47.336501  2.330000e+02
# 25%                             78.526993  1.099775e+04
# 50%                             83.424161  2.599650e+04
# 75%                             87.230051  6.801375e+04
# max                            100.000000  9.721138e+06
#
#        % Less than 18 Years of Age  % 65 and Over      % Black  \
# count                  2010.000000    2010.000000  2010.000000
# mean                     21.683466      20.450801     8.847672
# std                       3.581355       4.822241    13.945457
# min                       3.546634       6.299112     0.000000
# 25%                      19.602721      17.313146     0.843511
# 50%                      21.678597      20.104667     2.325080
# 75%                      23.638154      23.220098     9.722577
# max                      42.099541      42.459275    82.122697
#
#        % American Indian or Alaska Native      % Asian  \
# count                         2010.000000  2010.000000
# mean                             2.601479     1.695258
# std                              8.322901     3.082494
# min                              0.000000     0.000000
# 25%                              0.444085     0.537928
# 50%                              0.747352     0.818378
# 75%                              1.522712     1.520247
# max                             92.111621    46.380224
#
#        % Native Hawaiian or Other Pacific Islander   % Hispanic  \
# count                                  2010.000000  2010.000000
# mean                                      0.148835    10.194657
# std                                       0.396069    13.461868
# min                                       0.000000     0.732961
# 25%                                       0.040193     2.818790
# 50%                                       0.076756     5.100209
# 75%                                       0.141910    11.064310
# max                                      10.414296    95.291657
#
#        % Non-Hispanic White  % Not Proficient in English     % Female  \
# count           2010.000000                  2010.000000  2010.000000
# mean              75.060171                     1.568745    49.488312
# std               20.109038                     2.558139     2.297528
# min                2.693887                     0.000000    27.039544
# 25%               63.039319                     0.244788    48.963481
# 50%               82.132857                     0.682820    49.870434
# 75%               91.420332                     1.741557    50.613384
# max               97.539986                    32.084894    57.762420
#
#            % Rural
# count  2010.000000
# mean     64.276710
# std      33.679398
# min       0.000000
# 25%      35.612502
# 50%      67.478110
# 75%     100.000000
# max     100.000000

# %%
linear_pipe = Pipeline([('impute', KNNImputer()),
                        ('scale', StandardScaler()), #For coefficient size comparison
                        ('linreg', LinearRegression())])

linear_pipe.fit(X_train, y_train)
linear_train_preds = linear_pipe.predict(X_train)

# %%
forest_pipe = Pipeline([('impute', KNNImputer()),
                        ('rfr', RandomForestRegressor())])

forest_pipe.fit(X_train, y_train)
forest_train_preds = forest_pipe.predict(X_train)

# %%
print('XGB training RMSE: ', root_mean_squared_error(y_train, xgb_train_preds))
print('Linear training RMSE: ', root_mean_squared_error(y_train, linear_train_preds))
print('Random Forest training RMSE: ', root_mean_squared_error(y_train, forest_train_preds))
# Out:
# XGB RMSE:  0.015976972268687
# Linear RMSE:  0.4719816306215972
# Random Forest RMSE:  0.19995143440196442

# %%
xgb_holdout_preds = xgb_pipe.predict(X_holdout)
linear_holdout_preds = linear_pipe.predict(X_holdout)
forest_holdout_preds = forest_pipe.predict(X_holdout)

# %%
print('XGB holdout RMSE: ', root_mean_squared_error(y_holdout, xgb_holdout_preds))
print('Linear holdout RMSE: ', root_mean_squared_error(y_holdout, linear_holdout_preds))
print('Random Forest holdout RMSE: ', root_mean_squared_error(y_holdout, forest_holdout_preds))
# Out:
# XGB holdout RMSE:  0.55734045722899
# Linear holdout RMSE:  0.49654249928710603
# Random Forest holdout RMSE:  0.5700927028658015

# %%
#Possibly include cross validation here
