# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from seaborn import set_style

set_style('whitegrid')

pd.set_option('display.max_columns', None) #forces all columns to be displayed

# %%
# %run features.ipynb

# %%
national_data = pd.read_csv('../data/national_data_master.csv')
national_data.set_index(['FIPS','State','County'], inplace=True)

# %%
national_data.head()
# Out:
#    FIPS    State   County   Deaths  Years of Potential Life Lost Rate  \
# 0  1000  Alabama      NaN  98140.0                       11415.734833
# 1  1001  Alabama  Autauga    942.0                        9407.948438
# 2  1003  Alabama  Baldwin   3789.0                        8981.575353
# 3  1005  Alabama  Barbour    579.0                       13138.848362
# 4  1007  Alabama     Bibb    501.0                       12675.434581
#
#    % Fair or Poor Health  Average Number of Physically Unhealthy Days  \
# 0                   17.8                                     3.934735
# 1                   17.3                                     3.910265
# 2                   15.2                                     3.730943
# 3                   27.3                                     5.023488
# 4                   22.0                                     4.552795
#
#    Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# ...

# %%
national_data_reduced = national_data[my_features]

# %%
national_data_reduced.head()
# Out:
#                       % Adults with Diabetes  % Adults with Obesity  \
# FIPS State   County
# 1000 Alabama NaN                        13.3                   40.6
# 1001 Alabama Autauga                    10.7                   38.9
# 1003 Alabama Baldwin                     9.8                   37.2
# 1005 Alabama Barbour                    15.6                   43.4
# 1007 Alabama Bibb                       12.4                   39.6
#
#                       Life Expectancy  Drug Overdose Mortality Rate   Deaths  \
# FIPS State   County
# 1000 Alabama NaN            73.707861                     21.561302  98140.0
# 1001 Alabama Autauga        75.263497                      9.350765    942.0
# 1003 Alabama Baldwin        76.738314                     25.729422   3789.0
# 1005 Alabama Barbour        72.377024                           NaN    579.0
# 1007 Alabama Bibb           72.251369                     22.385721    501.0
#
# ...

# %%
national_data_reduced.corr()
# Out:
#                                              % Adults with Diabetes  \
# % Adults with Diabetes                                     1.000000
# % Adults with Obesity                                      0.679379
# Life Expectancy                                           -0.720968
# Drug Overdose Mortality Rate                               0.218501
# Deaths                                                    -0.023659
# Years of Potential Life Lost Rate                          0.729111
# % Fair or Poor Health                                      0.926738
# Average Number of Physically Unhealthy Days                0.768756
# Average Number of Mentally Unhealthy Days                  0.554607
# % Low Birthweight                                          0.620186
# % Driving Deaths with Alcohol Involvement                 -0.106899
# Chlamydia Rate                                             0.587305
# Injury Death Rate                                          0.314013
# ...

# %% [markdown]
# I am not entirely sure our labor splitting makes much sense for EDA purposes, other than in dealing with NANs and duplicates. We do need to see some interaction between health outcome variables and policy/demographic variables, for instance.

# %%
national_data_reduced.describe()
# Out:
#        % Adults with Diabetes  % Adults with Obesity  Life Expectancy  \
# count             3194.000000            3194.000000      3121.000000
# mean                10.557639              37.292642        75.779560
# std                  2.244906               4.576466         3.420515
# min                  5.600000              17.400000        55.918958
# 25%                  8.900000              35.000000        73.612730
# 50%                 10.200000              37.600000        75.881834
# 75%                 11.800000              40.200000        78.024915
# max                 22.200000              52.500000        98.902938
#
#        Drug Overdose Mortality Rate         Deaths  \
# count                   1950.000000    2937.000000
# mean                      28.985364    3084.906367
# std                       16.483194   16883.777093
# min                        4.859716      48.000000
# 25%                       17.710918     263.000000
# ...

# %%
national_data_reduced.isna().sum()
# Out:
# % Adults with Diabetes                            7
# % Adults with Obesity                             7
# Life Expectancy                                  80
# Drug Overdose Mortality Rate                   1251
# Deaths                                          264
# Years of Potential Life Lost Rate               264
# % Fair or Poor Health                             7
# Average Number of Physically Unhealthy Days       7
# Average Number of Mentally Unhealthy Days         7
# % Low Birthweight                               105
# % Driving Deaths with Alcohol Involvement        34
# Chlamydia Rate                                  153
# Injury Death Rate                               113
# Age-Adjusted Death Rate                          62
# Child Mortality Rate                           1112
# Infant Mortality Rate                          1944
# % Frequent Physical Distress                      7
# % Frequent Mental Distress                        7
# ...

# %% [markdown]
# A lot of these mortality rate data have a lot of null values.

# %%
national_data_reduced.nunique()
# Out:
# % Adults with Diabetes                          138
# % Adults with Obesity                           271
# Life Expectancy                                3120
# Drug Overdose Mortality Rate                   1948
# Deaths                                         1609
# Years of Potential Life Lost Rate              2936
# % Fair or Poor Health                           237
# Average Number of Physically Unhealthy Days    3193
# Average Number of Mentally Unhealthy Days      3193
# % Low Birthweight                              2986
# % Driving Deaths with Alcohol Involvement       911
# Chlamydia Rate                                 2418
# Injury Death Rate                              3085
# Age-Adjusted Death Rate                        3138
# Child Mortality Rate                           2083
# Infant Mortality Rate                          1251
# % Frequent Physical Distress                    179
# % Frequent Mental Distress                      175
# ...

# %%
national_data_reduced.reset_index().nunique()
# Out:
# FIPS                                           3201
# State                                            51
# County                                         1857
# % Adults with Diabetes                          138
# % Adults with Obesity                           271
# Life Expectancy                                3120
# Drug Overdose Mortality Rate                   1948
# Deaths                                         1609
# Years of Potential Life Lost Rate              2936
# % Fair or Poor Health                           237
# Average Number of Physically Unhealthy Days    3193
# Average Number of Mentally Unhealthy Days      3193
# % Low Birthweight                              2986
# % Driving Deaths with Alcohol Involvement       911
# Chlamydia Rate                                 2418
# Injury Death Rate                              3085
# Age-Adjusted Death Rate                        3138
# Child Mortality Rate                           2083
# ...

# %% [markdown]
# Nicely enough, there are no duplicate records according to the FIPS count of unique values.

# %%
national_data.dtypes
# Out:
# Deaths                                         float64
# Years of Potential Life Lost Rate              float64
# % Fair or Poor Health                          float64
# Average Number of Physically Unhealthy Days    float64
# Average Number of Mentally Unhealthy Days      float64
#                                                 ...
# % Hispanic                                     float64
# % Non-Hispanic White                           float64
# % Not Proficient in English                    float64
# % Female                                       float64
# % Rural                                        float64
# Length: 85, dtype: object

# %%
national_data.columns
# Out:
# Index(['Deaths', 'Years of Potential Life Lost Rate', '% Fair or Poor Health',
#        'Average Number of Physically Unhealthy Days',
#        'Average Number of Mentally Unhealthy Days', '% Low Birthweight',
#        '% Adults Reporting Currently Smoking', '% Adults with Obesity',
#        'Food Environment Index', '% Physically Inactive',
#        '% With Access to Exercise Opportunities', '% Excessive Drinking',
#        '% Driving Deaths with Alcohol Involvement', 'Chlamydia Rate',
#        'Teen Birth Rate', '% Uninsured', 'Primary Care Physicians Rate',
#        'Dentist Rate', 'Mental Health Provider Rate',
#        'Preventable Hospitalization Rate', '% with Annual Mammogram',
#        '% Vaccinated', '% Completed High School', '% Some College',
#        '% Unemployed', '% Children in Poverty', 'Income Ratio',
#        '% Children in Single-Parent Households', 'Social Association Rate',
#        'Injury Death Rate', 'Average Daily PM2.5',
# ...

# %%
national_data.dtypes #why won't this give me a scrollable element or a text file option?
# Out:
# Deaths                                         float64
# Years of Potential Life Lost Rate              float64
# % Fair or Poor Health                          float64
# Average Number of Physically Unhealthy Days    float64
# Average Number of Mentally Unhealthy Days      float64
#                                                 ...
# % Hispanic                                     float64
# % Non-Hispanic White                           float64
# % Not Proficient in English                    float64
# % Female                                       float64
# % Rural                                        float64
# Length: 85, dtype: object
