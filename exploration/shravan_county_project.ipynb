# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = r"../data/2024_county_health_release_data_-_v1.xlsx"
all_data = pd.read_excel(path, sheet_name=1, header = 1)

# %%
all_data.head()
# Out:
#    FIPS    State   County Unreliable   Deaths  \
# 0  1000  Alabama      NaN        NaN  98140.0
# 1  1001  Alabama  Autauga        NaN    942.0
# 2  1003  Alabama  Baldwin        NaN   3789.0
# 3  1005  Alabama  Barbour        NaN    579.0
# 4  1007  Alabama     Bibb        NaN    501.0
#
#    Years of Potential Life Lost Rate  95% CI - Low  95% CI - High  \
# 0                       11415.734833  11307.652847   11523.816818
# 1                        9407.948438   8508.880150   10307.016727
# 2                        8981.575353   8514.700923    9448.449784
# 3                       13138.848362  11474.734018   14802.962705
# 4                       12675.434581  10964.290135   14386.579028
#
#    National Z-Score  YPLL Rate (Hispanic (all races))  ...  \
# 0               NaN                               NaN  ...
# 1         -0.158592                               NaN  ...
# 2         -0.282176                       4784.741236  ...
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3201 entries, 0 to 3200
# Columns: 272 entries, FIPS to National Z-Score.33
# dtypes: float64(263), int64(1), object(8)
# memory usage: 6.6+ MB

# %%
all_data.tail()
# Out:
#        FIPS    State      County Unreliable  Deaths  \
# 3196  56037  Wyoming  Sweetwater        NaN   672.0
# 3197  56039  Wyoming       Teton        NaN   123.0
# 3198  56041  Wyoming       Uinta        NaN   320.0
# 3199  56043  Wyoming    Washakie        NaN   130.0
# 3200  56045  Wyoming      Weston        NaN    88.0
#
#       Years of Potential Life Lost Rate  95% CI - Low  95% CI - High  \
# 3196                        9732.214769   8682.142301   10782.287237
# 3197                        4267.876402   3065.624262    5470.128542
# 3198                       11027.136279   9256.647732   12797.624825
# 3199                        8065.688093   5678.764734   10452.611452
# 3200                        5905.489557   4065.067282    8293.502975
#
#       National Z-Score  YPLL Rate (Hispanic (all races))  ...  \
# 3196         -0.064602                       7167.468314  ...
# 3197         -1.648450                               NaN  ...
# ...

# %%
all_data.columns
# Out:
# Index(['FIPS', 'State', 'County', 'Unreliable', 'Deaths',
#        'Years of Potential Life Lost Rate', '95% CI - Low', '95% CI - High',
#        'National Z-Score', 'YPLL Rate (Hispanic (all races))',
#        ...
#        '% Drive Alone (Hispanic) 95% CI - Low',
#        '% Drive Alone (Hispanic) 95% CI - High', '% Drive Alone (White)',
#        '% Drive Alone (White) 95% CI - Low',
#        '% Drive Alone (White) 95% CI - High', '# Workers who Drive Alone',
#        '% Long Commute - Drives Alone', '95% CI - Low.19', '95% CI - High.19',
#        'National Z-Score.33'],
#       dtype='object', length=272)

# %%
numeric_data = all_data._get_numeric_data()

# %%
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3201 entries, 0 to 3200
# Columns: 264 entries, FIPS to National Z-Score.33
# dtypes: float64(263), int64(1)
# memory usage: 6.4 MB

# %%
numeric_data[['FIPS', 'Deaths',
       'Years of Potential Life Lost Rate', '95% CI - Low', '95% CI - High',
       'National Z-Score', 'YPLL Rate (Hispanic (all races))',
       '% Drive Alone (Hispanic) 95% CI - Low',
       '% Drive Alone (Hispanic) 95% CI - High', '% Drive Alone (White)',
       '% Drive Alone (White) 95% CI - Low',
       '% Drive Alone (White) 95% CI - High', '# Workers who Drive Alone',
       '% Long Commute - Drives Alone', '95% CI - Low.19', '95% CI - High.19',
       'National Z-Score.33']].corr()
# Out:
#                                             FIPS    Deaths  \
# FIPS                                    1.000000 -0.026926
# Deaths                                 -0.026926  1.000000
# Years of Potential Life Lost Rate      -0.030388 -0.073287
# 95% CI - Low                           -0.035087 -0.014623
# 95% CI - High                          -0.023867 -0.113671
# National Z-Score                       -0.040313 -0.130589
# YPLL Rate (Hispanic (all races))        0.101706 -0.111261
# % Drive Alone (Hispanic) 95% CI - Low   0.020974  0.095497
# % Drive Alone (Hispanic) 95% CI - High  0.072902 -0.299982
# % Drive Alone (White)                   0.057078 -0.178973
# % Drive Alone (White) 95% CI - Low      0.052509 -0.057887
# % Drive Alone (White) 95% CI - High     0.052543 -0.278847
# # Workers who Drive Alone              -0.027106  0.982911
# % Long Commute - Drives Alone           0.015373  0.040907
# 95% CI - Low.19                         0.005734  0.100279
# ...

# %%
x = numeric_data['% Adults with Obesity']
y = numeric_data['% Physically Inactive']

plt.scatter(x, y, alpha=0.5)
