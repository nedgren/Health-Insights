# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = r'../data/national-data-master.csv'
all_data = pd.read_csv(path)
train_file_path = r'../data/data-full-train.csv' 
train_data = pd.read_csv(train_file_path)

# %%
all_data.head()
# Out:
#    FIPS    State   County   Deaths  Years of Potential Life Lost Rate  \
# 0  1000  Alabama      NaN  98140.0                       11415.734833
# 1  1001  Alabama  Autauga    942.0                        9407.948438
# 2  1003  Alabama  Baldwin   3789.0                        8981.575353
# 3  1005  Alabama  Barbour    579.0                       13138.848362
# 4  1007  Alabama     Bibb    501.0                       12675.434581
#
#    % Fair or Poor Health  Average Number of Physically Unhealthy Days  \
# 0                   17.8                                     3.934735
# 1                   17.3                                     3.910265
# 2                   15.2                                     3.730943
# 3                   27.3                                     5.023488
# 4                   22.0                                     4.552795
#
#    Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3201 entries, 0 to 3200
# Data columns (total 88 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   FIPS                                                 3201 non-null   int64
#  1   State                                                3201 non-null   object
#  2   County                                               3150 non-null   object
#  3   Deaths                                               2937 non-null   float64
#  4   Years of Potential Life Lost Rate                    2937 non-null   float64
#  5   % Fair or Poor Health                                3194 non-null   float64
#  6   Average Number of Physically Unhealthy Days          3194 non-null   float64
#  7   Average Number of Mentally Unhealthy Days            3194 non-null   float64
# ...

# %%
all_data.tail()
# Out:
#        FIPS    State      County  Deaths  Years of Potential Life Lost Rate  \
# 3196  56037  Wyoming  Sweetwater   672.0                        9732.214769
# 3197  56039  Wyoming       Teton   123.0                        4267.876402
# 3198  56041  Wyoming       Uinta   320.0                       11027.136279
# 3199  56043  Wyoming    Washakie   130.0                        8065.688093
# 3200  56045  Wyoming      Weston    88.0                        5905.489557
#
#       % Fair or Poor Health  Average Number of Physically Unhealthy Days  \
# 3196                   14.4                                     3.637753
# 3197                   10.0                                     2.544521
# 3198                   14.1                                     3.405617
# 3199                   13.7                                     3.378598
# 3200                   14.8                                     3.564866
#
#       Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# ...

# %%
all_data.columns
# Out:
# Index(['FIPS', 'State', 'County', 'Deaths',
#        'Years of Potential Life Lost Rate', '% Fair or Poor Health',
#        'Average Number of Physically Unhealthy Days',
#        'Average Number of Mentally Unhealthy Days', '% Low Birthweight',
#        '% Adults Reporting Currently Smoking', '% Adults with Obesity',
#        'Food Environment Index', '% Physically Inactive',
#        '% With Access to Exercise Opportunities', '% Excessive Drinking',
#        '% Driving Deaths with Alcohol Involvement', 'Chlamydia Rate',
#        'Teen Birth Rate', '% Uninsured', 'Primary Care Physicians Rate',
#        'Dentist Rate', 'Mental Health Provider Rate',
#        'Preventable Hospitalization Rate', '% with Annual Mammogram',
#        '% Vaccinated', '% Completed High School', '% Some College',
#        '% Unemployed', '% Children in Poverty', 'Income Ratio',
#        '% Children in Single-Parent Households', 'Social Association Rate',
#        'Injury Death Rate', 'Average Daily PM2.5',
# ...

# %%
x = all_data['Injury Death Rate']
y = all_data['Drug Overdose Mortality Rate']

plt.xlim([0, 200])
plt.ylim([0, 100])

plt.scatter(x, y, alpha=0.25, s=2.5)

# %%
numeric_data = all_data._get_numeric_data()

# %%
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3201 entries, 0 to 3200
# Data columns (total 85 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   FIPS                                                 3201 non-null   int64
#  1   Deaths                                               2937 non-null   float64
#  2   Years of Potential Life Lost Rate                    2937 non-null   float64
#  3   % Fair or Poor Health                                3194 non-null   float64
#  4   Average Number of Physically Unhealthy Days          3194 non-null   float64
#  5   Average Number of Mentally Unhealthy Days            3194 non-null   float64
#  6   % Low Birthweight                                    3096 non-null   float64
#  7   % Adults Reporting Currently Smoking                 3194 non-null   float64
# ...

# %%
numeric_data.corr()
# Out:
#                                                  FIPS    Deaths  \
# FIPS                                         1.000000 -0.026926
# Deaths                                      -0.026926  1.000000
# Years of Potential Life Lost Rate           -0.030388 -0.073287
# % Fair or Poor Health                       -0.058751 -0.070192
# Average Number of Physically Unhealthy Days -0.074113 -0.112218
# ...                                               ...       ...
# % Hispanic                                   0.095071  0.092936
# % Non-Hispanic White                         0.048841 -0.123238
# % Not Proficient in English                  0.008921  0.148791
# % Female                                    -0.009038  0.069378
# % Rural                                      0.009860 -0.204688
#
#                                              Years of Potential Life Lost Rate  \
# FIPS                                                                 -0.030388
# ...

# %%
x = numeric_data['% Adults with Obesity']
y = numeric_data['% Physically Inactive']

plt.scatter(x, y, alpha=0.5)

# %%
policy_data = all_data[['% With Access to Exercise Opportunities', '% Uninsured',
'Primary Care Physicians Rate',
'Dentist Rate',
'Mental Health Provider Rate',
'Preventable Hospitalization Rate',
'% with Annual Mammogram',
'% Vaccinated', '% Adults with Obesity',
'% Adults with Diabetes',
'Life Expectancy',
'Drug Overdose Mortality Rate'
                     ]]

# %%
policy_columns = ['% With Access to Exercise Opportunities', '% Uninsured',
'Primary Care Physicians Rate',
'Dentist Rate',
'Mental Health Provider Rate',
'Preventable Hospitalization Rate',
'% with Annual Mammogram',
'% Vaccinated', '% Adults with Obesity',
'% Adults with Diabetes',
'Life Expectancy',
'Drug Overdose Mortality Rate'
                     ]

# %%
policy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3201 entries, 0 to 3200
# Data columns (total 12 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   % With Access to Exercise Opportunities  3149 non-null   float64
#  1   % Uninsured                              3193 non-null   float64
#  2   Primary Care Physicians Rate             3037 non-null   float64
#  3   Dentist Rate                             3107 non-null   float64
#  4   Mental Health Provider Rate              3009 non-null   float64
#  5   Preventable Hospitalization Rate         3124 non-null   float64
#  6   % with Annual Mammogram                  3172 non-null   float64
#  7   % Vaccinated                             3174 non-null   float64
#  8   % Adults with Obesity                    3194 non-null   float64
#  9   % Adults with Diabetes                   3194 non-null   float64
# ...

# %%
policy_data.head()
# Out:
#    % With Access to Exercise Opportunities  % Uninsured  \
# 0                                61.333795    11.693351
# 1                                54.491965    10.018560
# 2                                63.129350    10.997067
# 3                                54.854696    12.677634
# 4                                43.390302    11.379928
#
#    Primary Care Physicians Rate  Dentist Rate  Mental Health Provider Rate  \
# 0                      63.65235      49.60294                    135.09263
# 1                      43.99695      30.12099                     36.81454
# 2                      62.68440      47.07124                    110.37393
# 3                      40.05768      32.38080                     28.33320
# 4                      66.73488      22.72211                     49.98864
#
#    Preventable Hospitalization Rate  % with Annual Mammogram  % Vaccinated  \
# 0                            3280.0                     41.0          39.0
# ...

# %%
policy_data.isna().sum()
# Out:
# % With Access to Exercise Opportunities      52
# % Uninsured                                   8
# Primary Care Physicians Rate                164
# Dentist Rate                                 94
# Mental Health Provider Rate                 192
# Preventable Hospitalization Rate             77
# % with Annual Mammogram                      29
# % Vaccinated                                 27
# % Adults with Obesity                         7
# % Adults with Diabetes                        7
# Life Expectancy                              80
# Drug Overdose Mortality Rate               1251
# dtype: int64

# %%
policy_data.dropna()
# Out:
#       % With Access to Exercise Opportunities  % Uninsured  \
# 0                                   61.333795    11.693351
# 1                                   54.491965    10.018560
# 2                                   63.129350    10.997067
# 4                                   43.390302    11.379928
# 5                                   41.355227    12.819978
# ...                                       ...          ...
# 3188                                71.057187    13.013931
# 3189                                77.631377    19.112064
# 3190                                82.812832    13.891779
# 3196                                92.621593    15.548980
# 3198                                63.662592    14.431495
#
#       Primary Care Physicians Rate  Dentist Rate  Mental Health Provider Rate  \
# 0                         63.65235      49.60294                    135.09263
# 1                         43.99695      30.12099                     36.81454
# ...

# %% [markdown]
# Exploratory policy feature analysis on the training set:

# %%
target = '% Adults with Diabetes'
policy_data_train = data_train[policy_columns]

# %%
num_features = 12
num_cols = 3  # Number of columns in the grid
num_rows = (num_features + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5 * num_rows))
axes = axes.flatten() 

# Loop through the features and create scatter plots
for ax, feature in zip(axes, policy_columns):
    ax.scatter(policy_data_train[target], policy_data_train[feature])
    ax.set_xlabel(target)
    ax.set_ylabel(feature)
    ax.set_title(f'Scatter Plot of {feature} vs. % Adults with Diabetes')

for i in range(len(policy_columns), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %%
policy_data_train[['% With Access to Exercise Opportunities', '% Uninsured',
'Preventable Hospitalization Rate',
'% with Annual Mammogram',
'% Vaccinated', '% Adults with Obesity'
                     ]].mean(numeric_only=True)
# Out:
# % With Access to Exercise Opportunities      62.018923
# % Uninsured                                  11.479297
# Preventable Hospitalization Rate           2833.915075
# % with Annual Mammogram                      41.729492
# % Vaccinated                                 40.119600
# % Adults with Obesity                        37.350060
# dtype: float64

# %%
policy_data_train[['% With Access to Exercise Opportunities', '% Uninsured',
'Preventable Hospitalization Rate',
'% with Annual Mammogram',
'% Vaccinated', '% Adults with Obesity'
                     ]].median(numeric_only=True)
# Out:
# % With Access to Exercise Opportunities      64.748295
# % Uninsured                                  10.251583
# Preventable Hospitalization Rate           2729.000000
# % with Annual Mammogram                      42.000000
# % Vaccinated                                 41.000000
# % Adults with Obesity                        37.700000
# dtype: float64

# %%
policy_data_train['% Adults with Obesity'].max()
# Out:
# np.float64(52.5)

# %%
x = policy_data_train['% Adults with Obesity']
y = policy_data_train['% With Access to Exercise Opportunities']

plt.scatter(x, y, alpha=0.2)

# %%
policy_data_train['% With Access to Exercise Opportunities'].hist(bins = 100)
# Out:
# <Axes: >

# %%
x = policy_data_train['% Uninsured']
y = policy_data_train['% With Access to Exercise Opportunities']

plt.scatter(x, y, alpha=0.2)

# %%
policy_data_train['% Uninsured'].hist(bins = 100)
# Out:
# <Axes: >

# %%
x = policy_data_train['% Uninsured']
y = policy_data_train['% Vaccinated']

plt.scatter(x, y, alpha=0.2)
