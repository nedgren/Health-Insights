# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
#import data
filepath = '../data/data-reduced.csv'
data = pd.read_csv(filepath)

# %%
data.head()
# Out:
#    FIPS    State   County  % Adults with Diabetes  \
# 0  1001  Alabama  Autauga                    10.7
# 1  1003  Alabama  Baldwin                     9.8
# 2  1005  Alabama  Barbour                    15.6
# 3  1007  Alabama     Bibb                    12.4
# 4  1009  Alabama   Blount                    10.5
#
#    % Adults Reporting Currently Smoking  % Adults with Obesity  \
# 0                                  16.9                   38.9
# 1                                  15.0                   37.2
# 2                                  25.0                   43.4
# 3                                  22.0                   39.6
# 4                                  19.6                   37.7
#
#    Food Environment Index  % Physically Inactive  \
# 0                     6.7                   29.1
# 1                     7.5                   27.6
# 2                     6.0                   40.2
# 3                     7.6                   36.0
# ...

# %%
data_train, data_test = train_test_split(data,
                                         test_size=0.2,
                                         shuffle=True,
                                         random_state=708)

# %%
training_set_index = data_train.index
test_set_index = data_test.index

# %%
#check that target variable is well-distributed in both train and test sets
target = '% Adults with Diabetes'
plt.hist(data_train[target])
plt.hist(data_test[target])

plt.show()

# %%
data_train.to_csv('../data/data-reduced-train.csv', index=False)
data_test.to_csv('../data/data-reduced-test.csv', index=False)
